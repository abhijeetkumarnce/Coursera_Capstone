# %% [markdown]
# # The Battle of Neighborhood Project

# %% [markdown]
# Abhijeet Kumar

# %% [markdown]
# ## Import Required Libraries

# %%
import numpy as np # library to handle data in a vectorized manner
import time
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe


# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
import folium # map rendering library
from folium import plugins

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

import seaborn as sns

# import k-means from clustering stage
from sklearn.cluster import KMeans



print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         713 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.1.0-py_1 conda-forge
#     branca:  0.4.0-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# # Mapping Data

# %% [markdown]
# ### Singapore Map - Current residence and venues in neighborhood

# %%
# Shenton Way, District 01, Singapore
address = 'Mccallum Street, Singapore'
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Singapore home are {}, {}.'.format(latitude, longitude))
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.21.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   app.launch_new_instance()
# The geograpical coordinate of Singapore home are 1.2784801, 103.8493717.

# %%
neighborhood_latitude=1.2792655
neighborhood_longitude=103.8480938

# %% [markdown]
# ## Dial FourSquare to find venues around current residence in Singapore

# %%
CLIENT_ID = '1LKJ3H5YQD1CWDYZI3KMG5SUUBT1VQ4LH2OPWNWVPEZJDZWG' # your Foursquare ID
CLIENT_SECRET = '22DQWINEYATYJI4YPPM4IGZ0FWWIXX0320ODAWGFZNACA31J' # your Foursquare Secret
VERSION = '20200502' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 1LKJ3H5YQD1CWDYZI3KMG5SUUBT1VQ4LH2OPWNWVPEZJDZWG
# CLIENT_SECRET:22DQWINEYATYJI4YPPM4IGZ0FWWIXX0320ODAWGFZNACA31J

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=1LKJ3H5YQD1CWDYZI3KMG5SUUBT1VQ4LH2OPWNWVPEZJDZWG&client_secret=22DQWINEYATYJI4YPPM4IGZ0FWWIXX0320ODAWGFZNACA31J&v=20200502&ll=1.2792655,103.8480938&radius=500&limit=100'

# %%
# results display is hidden for report simplification 
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5eae77a3c8cff2001bfe28ba'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Financial District',
#   'headerFullLocation': 'Financial District, Singapore',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 154,
#   'suggestedBounds': {'ne': {'lat': 1.2837655045000045,
#     'lng': 103.85258652226942},
#    'sw': {'lat': 1.2747654954999954, 'lng': 103.84360107773058}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51b49e49abd88dd0b4e7330f',
#        'name': 'Napoleon Food & Wine Bar',
#        'location': {'address': '206 Telok Ayer Street',
#         'lat': 1.2799249387439204,
#         'lng': 103.84733300574288,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2799249387439204,
#           'lng': 103.84733300574288}],
#         'distance': 112,
#         'postalCode': '068641',
#         'cc': 'SG',
#         'neighborhood': 'Tanjong Pagar',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['206 Telok Ayer Street', '068641', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '58378307'}},
#       'referralId': 'e-0-51b49e49abd88dd0b4e7330f-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '586a792404aa4f25645e4e4e',
#        'name': 'Native',
#        'location': {'address': '52A Amoy Street',
#         'lat': 1.2801354244146959,
#         'lng': 103.84684430802805,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2801354244146959,
#           'lng': 103.84684430802805}],
#         'distance': 169,
#         'postalCode': '069878',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['52A Amoy Street', '069878', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-586a792404aa4f25645e4e4e-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56e9512acd10cabb2f042d09',
#        'name': 'Freehouse',
#        'location': {'address': '21A Boon Tat Street',
#         'lat': 1.2812544915596238,
#         'lng': 103.8485128808929,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2812544915596238,
#           'lng': 103.8485128808929}],
#         'distance': 226,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['21A Boon Tat Street', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d117941735',
#          'name': 'Beer Garden',
#          'pluralName': 'Beer Gardens',
#          'shortName': 'Beer Garden',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56e9512acd10cabb2f042d09-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f704af9e4b07a4bc6edd2a9',
#        'name': 'Sofitel So Singapore',
#        'location': {'address': '35 Robinson Road',
#         'lat': 1.280016815397146,
#         'lng': 103.84981314280776,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280016815397146,
#           'lng': 103.84981314280776}],
#         'distance': 208,
#         'postalCode': '068876',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['35 Robinson Road', '068876', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '150895632'}},
#       'referralId': 'e-0-4f704af9e4b07a4bc6edd2a9-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55a49050498e801fbf03be73',
#        'name': 'Park Bench Deli',
#        'location': {'address': '179 Telok Ayer St',
#         'crossStreet': 'Amoy St',
#         'lat': 1.2798723608759432,
#         'lng': 103.84728710112705,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2798723608759432,
#           'lng': 103.84728710112705}],
#         'distance': 112,
#         'postalCode': '068627',
#         'cc': 'SG',
#         'neighborhood': 'Chinatown',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['179 Telok Ayer St (Amoy St)',
#          '068627',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55a49050498e801fbf03be73-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50248ddde4b0bb3db3a6ff8a',
#        'name': 'Pepper Bowl',
#        'location': {'address': '#02-102, Amoy Street Food Centre',
#         'crossStreet': '7 Maxwell Rd.',
#         'lat': 1.279371,
#         'lng': 103.84671,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.279371,
#           'lng': 103.84671}],
#         'distance': 154,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-102, Amoy Street Food Centre (7 Maxwell Rd.)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50248ddde4b0bb3db3a6ff8a-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54e975f6498e0c8bb883ee29',
#        'name': 'Meat Smith',
#        'location': {'address': '167 Telok Ayer Street',
#         'lat': 1.2802049410855447,
#         'lng': 103.8474104901937,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2802049410855447,
#           'lng': 103.8474104901937}],
#         'distance': 129,
#         'postalCode': '068620',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['167 Telok Ayer Street', '068620', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d14f941735',
#          'name': 'Southern / Soul Food Restaurant',
#          'pluralName': 'Southern / Soul Food Restaurants',
#          'shortName': 'Southern / Soul',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '219625364'}},
#       'referralId': 'e-0-54e975f6498e0c8bb883ee29-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56ecb93dcd101850ebc08dc5',
#        'name': 'Mellower Coffee',
#        'location': {'address': '77 Robinson Road #01-03',
#         'lat': 1.2778141065087054,
#         'lng': 103.84818781617354,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2778141065087054,
#           'lng': 103.84818781617354}],
#         'distance': 161,
#         'postalCode': '068896',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['77 Robinson Road #01-03',
#          '068896',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56ecb93dcd101850ebc08dc5-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c57877d6201e21e49b7e86e',
#        'name': 'PS.Cafe',
#        'location': {'address': '45 Ann Siang Hill #02-02',
#         'crossStreet': 'Ann Siang Hill Park',
#         'lat': 1.2804684376763578,
#         'lng': 103.8462642876152,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2804684376763578,
#           'lng': 103.8462642876152}],
#         'distance': 243,
#         'postalCode': '069719',
#         'cc': 'SG',
#         'neighborhood': 'Chinatown',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['45 Ann Siang Hill #02-02 (Ann Siang Hill Park)',
#          '069719',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c57877d6201e21e49b7e86e-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fc8aecee4b08eb1f57a1a81',
#        'name': 'Anglo Indian Cafe & Bar',
#        'location': {'address': '1 Shenton Way',
#         'lat': 1.2790836483039665,
#         'lng': 103.85012677894278,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2790836483039665,
#           'lng': 103.85012677894278}],
#         'distance': 227,
#         'postalCode': '068803',
#         'cc': 'SG',
#         'neighborhood': 'Financial District',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Shenton Way', '068803', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fc8aecee4b08eb1f57a1a81-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52c54d0411d2a3d73dae49f6',
#        'name': 'Lau Pa Sat Satay Street',
#        'location': {'address': 'Boon Tat Street',
#         'lat': 1.280261,
#         'lng': 103.850235,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280261,
#           'lng': 103.850235}],
#         'distance': 262,
#         'postalCode': '048582',
#         'cc': 'SG',
#         'neighborhood': 'Financial District',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Boon Tat Street', '048582', 'Singapore']},
#        'categories': [{'id': '53e0feef498e5aac066fd8a9',
#          'name': 'Street Food Gathering',
#          'pluralName': 'Street Food Gatherings',
#          'shortName': 'Street Food Gathering',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52c54d0411d2a3d73dae49f6-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6a6236f964a5200fd42be3',
#        'name': 'Coffee Break',
#        'location': {'address': '#02-78 Amoy Street Food Centre',
#         'crossStreet': '7 Maxwell Road',
#         'lat': 1.2795293,
#         'lng': 103.846695,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2795293,
#           'lng': 103.846695}],
#         'distance': 158,
#         'postalCode': '069111',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-78 Amoy Street Food Centre (7 Maxwell Road)',
#          '069111',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6a6236f964a5200fd42be3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bab10b9364d97002cc5e458',
#        'name': 'Muchachos',
#        'location': {'address': '#01-01 Frasers Tower',
#         'crossStreet': '182 Cecil Street',
#         'lat': 1.2790721332821124,
#         'lng': 103.84702556749504,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2790721332821124,
#           'lng': 103.84702556749504}],
#         'distance': 120,
#         'postalCode': '069547',
#         'cc': 'SG',
#         'neighborhood': 'Financial District',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-01 Frasers Tower (182 Cecil Street)',
#          '069547',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d153941735',
#          'name': 'Burrito Place',
#          'pluralName': 'Burrito Places',
#          'shortName': 'Burritos',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burrito_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bab10b9364d97002cc5e458-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '597012f67269fe3e6b17ab13',
#        'name': 'The Providore',
#        'location': {'address': '6A Shenton Way OUE Gallery B1-07',
#         'lat': 1.2780488836327972,
#         'lng': 103.84939915153375,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2780488836327972,
#           'lng': 103.84939915153375}],
#         'distance': 198,
#         'postalCode': '068809',
#         'cc': 'SG',
#         'neighborhood': 'Financial District',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['6A Shenton Way OUE Gallery B1-07',
#          '068809',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-597012f67269fe3e6b17ab13-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '551bd574498e5f30136a811e',
#        'name': 'FYR Cycene Ond Drinc',
#        'location': {'address': '19 Boon Tat Street',
#         'lat': 1.2812964408600642,
#         'lng': 103.8484369192239,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2812964408600642,
#           'lng': 103.8484369192239}],
#         'distance': 229,
#         'postalCode': '069619',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['19 Boon Tat Street', '069619', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-551bd574498e5f30136a811e-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b305537f964a520fef824e3',
#        'name': 'Amoy Street Food Centre',
#        'location': {'address': '7 Maxwell Rd',
#         'crossStreet': 'Telok Ayer St / Amoy St',
#         'lat': 1.2795923,
#         'lng': 103.8467,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2795923,
#           'lng': 103.8467}],
#         'distance': 159,
#         'postalCode': '069111',
#         'cc': 'SG',
#         'neighborhood': 'Financial District',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['7 Maxwell Rd (Telok Ayer St / Amoy St)',
#          '069111',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b305537f964a520fef824e3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53db460f498e18a343d830db',
#        'name': 'Pantler',
#        'location': {'address': '198 Telok Ayer St',
#         'lat': 1.280137,
#         'lng': 103.847256,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280137,
#           'lng': 103.847256}],
#         'distance': 134,
#         'postalCode': '068637',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['198 Telok Ayer St', '068637', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53db460f498e18a343d830db-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '553b2460498e8cfc0a3cdc32',
#        'name': 'Yen Yakiniku',
#        'location': {'address': '15 Ann Siang Road',
#         'lat': 1.2810744259693214,
#         'lng': 103.84574260981839,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2810744259693214,
#           'lng': 103.84574260981839}],
#         'distance': 330,
#         'postalCode': '069695',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['15 Ann Siang Road', '069695', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-553b2460498e8cfc0a3cdc32-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58181cfd38fa17eb24ba32fa',
#        'name': 'Virgin Active',
#        'location': {'address': '#06-01 Guoco Tower',
#         'crossStreet': '7 Wallich Street',
#         'lat': 1.2770546200166835,
#         'lng': 103.84643542061019,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2770546200166835,
#           'lng': 103.84643542061019}],
#         'distance': 307,
#         'postalCode': '078884',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#06-01 Guoco Tower (7 Wallich Street)',
#          '078884',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58181cfd38fa17eb24ba32fa-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca579c7d971b1f7593ef7e0',
#        'name': 'Han Kee Fish Soup',
#        'location': {'address': '#02-129, Amoy Street Food Centre',
#         'crossStreet': '7 Maxwell Road',
#         'lat': 1.2794006,
#         'lng': 103.846596,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2794006,
#           'lng': 103.846596}],
#         'distance': 167,
#         'postalCode': '069111',
#         'cc': 'SG',
#         'neighborhood': 'Financial District',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-129, Amoy Street Food Centre (7 Maxwell Road)',
#          '069111',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1dd931735',
#          'name': 'Soup Place',
#          'pluralName': 'Soup Places',
#          'shortName': 'Soup',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/soup_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca579c7d971b1f7593ef7e0-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d24773df39ca14334e675b8',
#        'name': 'Quan Ji @ Amoy Street Food Market',
#        'location': {'address': '#01-56/57 7 Maxwell Road',
#         'lat': 1.2791000736241216,
#         'lng': 103.84739222011355,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2791000736241216,
#           'lng': 103.84739222011355}],
#         'distance': 80,
#         'postalCode': '069111',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-56/57 7 Maxwell Road',
#          '069111',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d24773df39ca14334e675b8-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59256e0228122f403d2959ab',
#        'name': 'Nouri',
#        'location': {'address': '72 Amoy Street',
#         'lat': 1.2802674,
#         'lng': 103.84675,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2802674,
#           'lng': 103.84675}],
#         'distance': 186,
#         'postalCode': '069893',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['72 Amoy Street', '069893', 'Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f9',
#          'name': 'Modern European Restaurant',
#          'pluralName': 'Modern European Restaurants',
#          'shortName': 'Modern European',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59256e0228122f403d2959ab-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e741c8baeb780be09a0321f',
#        'name': 'Sarnies',
#        'location': {'address': '136 Telok Ayer St',
#         'lat': 1.2815286862041824,
#         'lng': 103.84811698897273,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2815286862041824,
#           'lng': 103.84811698897273}],
#         'distance': 251,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['136 Telok Ayer St', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e741c8baeb780be09a0321f-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '557a6b3c498ed9cb15987433',
#        'name': 'ShuKuu Izakaya',
#        'location': {'address': '8 Stanley Street',
#         'lat': 1.280110799343203,
#         'lng': 103.8477615067585,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280110799343203,
#           'lng': 103.8477615067585}],
#         'distance': 101,
#         'postalCode': '068727',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['8 Stanley Street', '068727', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-557a6b3c498ed9cb15987433-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e5e1aefe4cdfc603ed5c7c3',
#        'name': '왕대박 Wang Dae Bak Korean BBQ Restaurant',
#        'location': {'address': '98 Amoy St',
#         'lat': 1.281345203093981,
#         'lng': 103.84755092069813,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.281345203093981,
#           'lng': 103.84755092069813}],
#         'distance': 239,
#         'postalCode': '069918',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['98 Amoy St', '069918', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e5e1aefe4cdfc603ed5c7c3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d08478ec26ba143728f1817',
#        'name': '6oz Espresso Bar',
#        'location': {'address': '#01-K1, Tokio Marine Centre',
#         'crossStreet': '20 McCallum St',
#         'lat': 1.279543363638627,
#         'lng': 103.84803324937819,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.279543363638627,
#           'lng': 103.84803324937819}],
#         'distance': 31,
#         'postalCode': '069046',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-K1, Tokio Marine Centre (20 McCallum St)',
#          '069046',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d08478ec26ba143728f1817-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51c2c98f8bbda6c871fa0bcc',
#        'name': 'The Westin Singapore',
#        'location': {'address': 'Asia Square Tower 2, 12 Marina View',
#         'lat': 1.2782748644512303,
#         'lng': 103.85077194308906,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2782748644512303,
#           'lng': 103.85077194308906}],
#         'distance': 317,
#         'postalCode': '018961',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'state': 'SG-01',
#         'country': 'Singapore',
#         'formattedAddress': ['Asia Square Tower 2, 12 Marina View',
#          '018961',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '63746181'}},
#       'referralId': 'e-0-51c2c98f8bbda6c871fa0bcc-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '506daac8e4b09e74d871828c',
#        'name': 'Lolla',
#        'location': {'address': '22 Ann Siang Hill',
#         'crossStreet': 'Ann Siang Road',
#         'lat': 1.2810338519455675,
#         'lng': 103.84570753754707,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2810338519455675,
#           'lng': 103.84570753754707}],
#         'distance': 330,
#         'postalCode': '069702',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['22 Ann Siang Hill (Ann Siang Road)',
#          '069702',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-506daac8e4b09e74d871828c-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '559bcec1498ef1434e22b3c6',
#        'name': "L'Operetta Corner Bar",
#        'location': {'lat': 1.2813980779857868,
#         'lng': 103.84816324142832,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2813980779857868,
#           'lng': 103.84816324142832}],
#         'distance': 237,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-559bcec1498ef1434e22b3c6-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55dd3b2f498ee2d1c9ec32ec',
#        'name': 'Grain Traders',
#        'location': {'address': '#01-01/02/03, CapitaGreen',
#         'crossStreet': '138 Market Street',
#         'lat': 1.281468,
#         'lng': 103.850039,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.281468,
#           'lng': 103.850039}],
#         'distance': 327,
#         'postalCode': '048946',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-01/02/03, CapitaGreen (138 Market Street)',
#          '048946',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55dd3b2f498ee2d1c9ec32ec-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b05880bf964a520eaad22e3',
#        'name': 'The Scarlet',
#        'location': {'address': '33 Erskine Road',
#         'lat': 1.2807069667371653,
#         'lng': 103.84543116452546,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2807069667371653,
#           'lng': 103.84543116452546}],
#         'distance': 336,
#         'postalCode': '069333',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['33 Erskine Road', '069333', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b05880bf964a520eaad22e3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c85b017d4e23704ca4d8588',
#        'name': 'SAP Thai Food',
#        'location': {'address': '#01-58, Amoy Street Food Centre',
#         'crossStreet': '7 Maxwell Road',
#         'lat': 1.2791002935317128,
#         'lng': 103.84709404520191,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2791002935317128,
#           'lng': 103.84709404520191}],
#         'distance': 112,
#         'postalCode': '069111',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-58, Amoy Street Food Centre (7 Maxwell Road)',
#          '069111',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'shortName': 'Thai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c85b017d4e23704ca4d8588-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5550d029498ece2b65824efd',
#        'name': 'Hyang Yeon (향연)',
#        'location': {'address': '#01-01 80 Amoy Street',
#         'lat': 1.2805355867345907,
#         'lng': 103.84690264038922,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2805355867345907,
#           'lng': 103.84690264038922}],
#         'distance': 193,
#         'postalCode': '069899',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-01 80 Amoy Street', '069899', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5550d029498ece2b65824efd-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d6b9a124395a1cd8620a973',
#        'name': 'Good Day 好日',
#        'location': {'address': '#01-25 Amoy Street Food Centre',
#         'crossStreet': '7 Maxwell Road',
#         'lat': 1.2794284177534678,
#         'lng': 103.84722539306422,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2794284177534678,
#           'lng': 103.84722539306422}],
#         'distance': 98,
#         'postalCode': '069111',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-25 Amoy Street Food Centre (7 Maxwell Road)',
#          '069111',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d6b9a124395a1cd8620a973-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a0a815ab546184394622ff6',
#        'name': 'Common Man Stan',
#        'location': {'address': '11/12 Stanley Street',
#         'lat': 1.2803394109655468,
#         'lng': 103.8478881267848,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2803394109655468,
#           'lng': 103.8478881267848}],
#         'distance': 121,
#         'postalCode': '068734',
#         'cc': 'SG',
#         'state': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['11/12 Stanley Street', '068734', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a0a815ab546184394622ff6-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4df741991f6e94c2c77ef6da',
#        'name': "Luke's Oyster Bar & Chop House",
#        'location': {'address': '20 Gemmill Lane',
#         'lat': 1.2824588279356128,
#         'lng': 103.84724044318698,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2824588279356128,
#           'lng': 103.84724044318698}],
#         'distance': 367,
#         'postalCode': '069256',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['20 Gemmill Lane', '069256', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4df741991f6e94c2c77ef6da-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b13fe99f964a520659b23e3',
#        'name': 'Lau Pa Sat Festival Market',
#        'location': {'address': '18 Raffles Quay',
#         'crossStreet': '1 Boon Tat St.',
#         'lat': 1.2805818978847052,
#         'lng': 103.85044020580223,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2805818978847052,
#           'lng': 103.85044020580223}],
#         'distance': 299,
#         'postalCode': '048582',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['18 Raffles Quay (1 Boon Tat St.)',
#          '048582',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b13fe99f964a520659b23e3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51edec76498eac13c849ed6d',
#        'name': 'SaladStop!',
#        'location': {'address': '168 Robinson Rd.',
#         'crossStreet': '168 Robinson Rd',
#         'lat': 1.2776191483677826,
#         'lng': 103.84799727047803,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2776191483677826,
#           'lng': 103.84799727047803}],
#         'distance': 183,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['168 Robinson Rd. (168 Robinson Rd)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1bd941735',
#          'name': 'Salad Place',
#          'pluralName': 'Salad Places',
#          'shortName': 'Salad',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51edec76498eac13c849ed6d-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ebc743a02d5e32b7b72a3bb',
#        'name': 'Pure Fitness',
#        'location': {'address': 'Level 6, Asia Square Tower 1',
#         'crossStreet': '8 Marina View',
#         'lat': 1.2786308470437144,
#         'lng': 103.85148741278418,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2786308470437144,
#           'lng': 103.85148741278418}],
#         'distance': 384,
#         'postalCode': '018960',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Level 6, Asia Square Tower 1 (8 Marina View)',
#          '018960',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ebc743a02d5e32b7b72a3bb-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dd72527cc3f75159f1dfaf3',
#        'name': 'Jewel Coffee',
#        'location': {'address': '#01-07, One Shenton',
#         'crossStreet': '1 Shenton Way',
#         'lat': 1.279097207942327,
#         'lng': 103.85035435608579,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.279097207942327,
#           'lng': 103.85035435608579}],
#         'distance': 252,
#         'postalCode': '068803',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-07, One Shenton (1 Shenton Way)',
#          '068803',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dd72527cc3f75159f1dfaf3-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5beed4bb9411f20038c1f8f8',
#        'name': 'The Other Roof',
#        'location': {'address': '28 Ann Siang Road',
#         'lat': 1.28083,
#         'lng': 103.845763,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.28083,
#           'lng': 103.845763}],
#         'distance': 312,
#         'postalCode': '069708',
#         'cc': 'SG',
#         'neighborhood': 'Chinatown',
#         'city': 'Tanjong Pagar',
#         'state': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['28 Ann Siang Road', '069708', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5beed4bb9411f20038c1f8f8-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
# ...
#         'country': 'Singapore',
#         'formattedAddress': ['138 Market Street CapitaGreen Level 40',
#          'Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f9',
#          'name': 'Modern European Restaurant',
#          'pluralName': 'Modern European Restaurants',
#          'shortName': 'Modern European',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-566a5a1d498e0e75b36aa41d-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b05880ef964a520e4ae22e3',
#        'name': 'Thian Hock Keng (Temple) (Thian Hock Keng)',
#        'location': {'address': '158 Telok Ayer St.',
#         'lat': 1.2809799675137736,
#         'lng': 103.84773410854318,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2809799675137736,
#           'lng': 103.84773410854318}],
#         'distance': 195,
#         'postalCode': '068613',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['158 Telok Ayer St.', '068613', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d13a941735',
#          'name': 'Temple',
#          'pluralName': 'Temples',
#          'shortName': 'Temple',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_temple_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b05880ef964a520e4ae22e3-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5881fc4924f6110c4752d2ef',
#        'name': 'Imakatsu',
#        'location': {'address': '#01-06 Guoco Tower',
#         'crossStreet': '7 Wallich Street',
#         'lat': 1.276605335377591,
#         'lng': 103.84582308538853,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.276605335377591,
#           'lng': 103.84582308538853}],
#         'distance': 389,
#         'postalCode': '078884',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-06 Guoco Tower (7 Wallich Street)',
#          '078884',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5881fc4924f6110c4752d2ef-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1bc6bef964a52052fd23e3',
#        'name': 'Fitness First Platinum',
#        'location': {'address': '#09-01, Capital Tower',
#         'crossStreet': '168 Robinson Rd',
#         'lat': 1.277843050928686,
#         'lng': 103.84765377406228,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.277843050928686,
#           'lng': 103.84765377406228}],
#         'distance': 165,
#         'postalCode': '068912',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#09-01, Capital Tower (168 Robinson Rd)',
#          '068912',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1bc6bef964a52052fd23e3-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51a49cd7498e45605109bc28',
#        'name': 'Yoga Movement',
#        'location': {'address': '21 Tanjong Pagar Rd',
#         'crossStreet': 'Murray St',
#         'lat': 1.279561008004445,
#         'lng': 103.84402560835365,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.279561008004445,
#           'lng': 103.84402560835365}],
#         'distance': 453,
#         'postalCode': '088444',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['21 Tanjong Pagar Rd (Murray St)',
#          '088444',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51a49cd7498e45605109bc28-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '511b32ade4b028f8d3314584',
#        'name': 'a noodle story',
#        'location': {'address': '#01-39 Amoy Street Food Centre',
#         'crossStreet': '7 Maxwell Rd',
#         'lat': 1.2793912,
#         'lng': 103.84661,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2793912,
#           'lng': 103.84661}],
#         'distance': 165,
#         'postalCode': '069111',
#         'cc': 'SG',
#         'neighborhood': 'Financial District',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-39 Amoy Street Food Centre (7 Maxwell Rd)',
#          '069111',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'shortName': 'Noodles',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-511b32ade4b028f8d3314584-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '566b5dbc498e50a39a4d4c29',
#        'name': 'Urban Roti',
#        'location': {'address': '18 Raffles Quay, #01-96',
#         'crossStreet': 'Lau Pa Sat Telok Ayer Festive Market',
#         'lat': 1.2802443099838159,
#         'lng': 103.85065019741309,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2802443099838159,
#           'lng': 103.85065019741309}],
#         'distance': 304,
#         'postalCode': '048582',
#         'cc': 'SG',
#         'neighborhood': 'Financial District',
#         'city': 'Singapore 048582',
#         'country': 'Singapore',
#         'formattedAddress': ['18 Raffles Quay, #01-96 (Lau Pa Sat Telok Ayer Festive Market)',
#          '048582',
#          'Singapore']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dfdd',
#          'name': 'North Indian Restaurant',
#          'pluralName': 'North Indian Restaurants',
#          'shortName': 'North Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-566b5dbc498e50a39a4d4c29-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d53753b5c9d236a282bf3ce',
#        'name': 'Otto Ristorante Italiano',
#        'location': {'address': '#01-02 Red Dot Traffic Building',
#         'lat': 1.2779313695606225,
#         'lng': 103.84613475409516,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2779313695606225,
#           'lng': 103.84613475409516}],
#         'distance': 263,
#         'postalCode': '069115',
#         'cc': 'SG',
#         'neighborhood': 'Tanjong Pagar',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-02 Red Dot Traffic Building',
#          '069115',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d53753b5c9d236a282bf3ce-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52b29d0f11d21316392a15e4',
#        'name': 'Tippling Club',
#        'location': {'address': '38 Tanjong Pagar Road',
#         'lat': 1.279419789447784,
#         'lng': 103.84384825925842,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.279419789447784,
#           'lng': 103.84384825925842}],
#         'distance': 472,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['38 Tanjong Pagar Road', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52b29d0f11d21316392a15e4-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58c779dacc5b6a0e960aff7a',
#        'name': 'Hamburg Steak Keisuke',
#        'location': {'address': '72 Peck Seah Street',
#         'lat': 1.2773080137025707,
#         'lng': 103.84502142686817,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2773080137025707,
#           'lng': 103.84502142686817}],
#         'distance': 405,
#         'postalCode': '079329',
#         'cc': 'SG',
#         'neighborhood': 'Financial District',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['72 Peck Seah Street', '079329', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58c779dacc5b6a0e960aff7a-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ccad71a31fd14002c4bff23',
#        'name': 'Heart Of Darkness',
#        'location': {'address': '55 Tras Street',
#         'lat': 1.2779609,
#         'lng': 103.84446,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2779609,
#           'lng': 103.84446}],
#         'distance': 429,
#         'postalCode': '078994',
#         'cc': 'SG',
#         'neighborhood': 'Chinatown',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['55 Tras Street', '078994', 'Singapore']},
#        'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#          'name': 'Beer Bar',
#          'pluralName': 'Beer Bars',
#          'shortName': 'Beer Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ccad71a31fd14002c4bff23-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5832ed3d6b0cdb3ef0437a72',
#        'name': 'Guzman y Gomez',
#        'location': {'address': '#B2-14 Guoco Tower',
#         'crossStreet': '7 Wallich Street',
#         'lat': 1.2768861,
#         'lng': 103.84526,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2768861,
#           'lng': 103.84526}],
#         'distance': 411,
#         'postalCode': '078884',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B2-14 Guoco Tower (7 Wallich Street)',
#          '078884',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5832ed3d6b0cdb3ef0437a72-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4e6d92f964a5206aed26e3',
#        'name': 'Starbucks',
#        'location': {'address': '#01-01/02 Capital Tower',
#         'crossStreet': '168 Robinson Rd',
#         'lat': 1.2775642048961309,
#         'lng': 103.84705793431091,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2775642048961309,
#           'lng': 103.84705793431091}],
#         'distance': 221,
#         'postalCode': '068912',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-01/02 Capital Tower (168 Robinson Rd)',
#          '068912',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4e6d92f964a5206aed26e3-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52c16fb3498e747963cf6a57',
#        'name': 'Tao Seafood Asia',
#        'location': {'address': '12 Marina View, Asia Square Tower 2, #02-10',
#         'lat': 1.2782001452351262,
#         'lng': 103.85093879544215,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2782001452351262,
#           'lng': 103.85093879544215}],
#         'distance': 338,
#         'postalCode': '018961',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['12 Marina View, Asia Square Tower 2, #02-10',
#          '018961',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52c16fb3498e747963cf6a57-99'}]}]}}

# %% [markdown]
# #### function that extracts the category of the venue - borrow from the Foursquare lab.

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
SGnearby_venues = json_normalize(venues) # flatten JSON
# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
SGnearby_venues =SGnearby_venues.loc[:, filtered_columns]
# filter the category for each row
SGnearby_venues['venue.categories'] = SGnearby_venues.apply(get_category_type, axis=1)
# clean columns
SGnearby_venues.columns = [col.split(".")[-1] for col in SGnearby_venues.columns]

SGnearby_venues.shape
# Out:
# (100, 4)

# %%
# Venues near current Singapore residence place
SGnearby_venues.head(10)
# Out:
#                        name                       categories       lat  \
# 0  Napoleon Food & Wine Bar                         Wine Bar  1.279925
# 1                    Native                     Cocktail Bar  1.280135
# 2                 Freehouse                      Beer Garden  1.281254
# 3      Sofitel So Singapore                            Hotel  1.280017
# 4           Park Bench Deli                    Deli / Bodega  1.279872
# 5               Pepper Bowl                 Asian Restaurant  1.279371
# 6                Meat Smith  Southern / Soul Food Restaurant  1.280205
# 7           Mellower Coffee                             Café  1.277814
# 8                   PS.Cafe                             Café  1.280468
# 9   Anglo Indian Cafe & Bar                Indian Restaurant  1.279084
#
#           lng
# 0  103.847333
# 1  103.846844
# 2  103.848513
# 3  103.849813
# 4  103.847287
# 5  103.846710
# 6  103.847410
# 7  103.848188
# 8  103.846264
# 9  103.850127

# %% [markdown]
# ### Map of Singapore residence place with venues in Neighborhood - for reference

# %%
latitude=1.2792655
longitude=103.8480938
# create map of Singapore place  using latitude and longitude values
map_sg = folium.Map(location=[latitude, longitude], zoom_start=18)
# add markers to map
for lat, lng, label in zip(SGnearby_venues['lat'], SGnearby_venues['lng'], SGnearby_venues['name']):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=30,
        radius=7,
        popup=label,
        color='blue',
        fill_color='#0f0f0f',
        fill_opacity=0.6,
    ).add_to(map_sg)  
    
map_sg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # DATA AND MAPPING

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_03d269dcb9d842f3a697a2cdf4a866f1 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='Gz2-GC9S76x_k_NqjaXgvzhZSuw-SXoPV55E59FUIZzH',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_03d269dcb9d842f3a697a2cdf4a866f1.get_object(Bucket='capstoneproject-donotdelete-pr-zmnovm1tp62gg3',Key='mh_neigh_data.xlsx')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

manhattan_data = pd.read_excel(body)
manhattan_data.head()
# Out:
#      Borough        Neighborhood   Latitude  Longitude  Cluster Labels
# 0  Manhattan         Marble Hill  40.876551 -73.910660               2
# 1  Manhattan           Chinatown  40.715618 -73.994279               2
# 2  Manhattan  Washington Heights  40.851903 -73.936900               4
# 3  Manhattan              Inwood  40.867684 -73.921210               3
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688               0

# %%
manhattan_data.tail()
# Out:
#       Borough     Neighborhood   Latitude  Longitude  Cluster Labels
# 35  Manhattan       Turtle Bay  40.752042 -73.967708               3
# 36  Manhattan       Tudor City  40.746917 -73.971219               3
# 37  Manhattan  Stuyvesant Town  40.731000 -73.974052               4
# 38  Manhattan         Flatiron  40.739673 -73.990947               3
# 39  Manhattan     Hudson Yards  40.756658 -74.000111               2

# %% [markdown]
# ## Manhattan Borough neighborhoods - data with top 10 clustered venues

# %%
body = client_03d269dcb9d842f3a697a2cdf4a866f1.get_object(Bucket='capstoneproject-donotdelete-pr-zmnovm1tp62gg3',Key='manhattan_merged.xlsx')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

manhattan_merged = pd.read_excel(body)
manhattan_merged.head()
# Out:
#      Borough        Neighborhood   Latitude  Longitude  Cluster Labels  \
# 0  Manhattan         Marble Hill  40.876551 -73.910660               2
# 1  Manhattan           Chinatown  40.715618 -73.994279               2
# 2  Manhattan  Washington Heights  40.851903 -73.936900               4
# 3  Manhattan              Inwood  40.867684 -73.921210               3
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688               0
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0           Coffee Shop        Discount Store           Yoga Studio
# 1    Chinese Restaurant          Cocktail Bar    Dim Sum Restaurant
# 2                  Café                Bakery     Mobile Phone Shop
# 3    Mexican Restaurant                Lounge           Pizza Place
# 4    Mexican Restaurant           Coffee Shop                  Café
#
#   4th Most Common Venue  5th Most Common Venue 6th Most Common Venue  \
# 0            Steakhouse        Supplement Shop        Tennis Stadium
# 1   American Restaurant  Vietnamese Restaurant    Salon / Barbershop
# 2           Pizza Place         Sandwich Place                  Park
# 3                  Café               Wine Bar                Bakery
# 4         Deli / Bodega            Pizza Place          Liquor Store
#
#   7th Most Common Venue      8th Most Common Venue 9th Most Common Venue  \
# 0            Shoe Store                        Gym                  Bank
# 1          Noodle House                     Bakery       Bubble Tea Shop
# 2                   Gym  Latin American Restaurant      Tapas Restaurant
# 3   American Restaurant                       Park    Frozen Yogurt Shop
# 4     Indian Restaurant           Sushi Restaurant        Sandwich Place
#
#   10th Most Common Venue
# 0     Seafood Restaurant
# 1         Ice Cream Shop
# 2     Mexican Restaurant
# 3     Spanish Restaurant
# 4            Yoga Studio

# %% [markdown]
# ## Map of Manhattan neighborhoods with top 10 clustered venues

# %%
# create map of Manhattan using latitude and longitude values from Nominatim
latitude= 40.7308619
longitude= -73.9871558 

kclusters=5
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=13)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Neighborhood'], manhattan_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=20,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
  # add markers for rental places to map
for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_clusters)    
    
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Examine a paticular Cluster

# %% [markdown]
# #### After examining several cluster data , I concluded that cluster # 2 resembles closer the Singapore place, therefore providing guidance as to where to look for the future apartment. Assign a value to 'kk' to explore a given cluster.

# %%
## kk is the cluster number to explore
kk = 2
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == kk, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#            Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0           Marble Hill           Coffee Shop        Discount Store
# 1             Chinatown    Chinese Restaurant          Cocktail Bar
# 6        Central Harlem    African Restaurant    Seafood Restaurant
# 9             Yorkville           Coffee Shop                   Gym
# 14              Clinton               Theater    Italian Restaurant
# 23                 Soho        Clothing Store              Boutique
# 26  Morningside Heights           Coffee Shop   American Restaurant
# 34         Sutton Place  Gym / Fitness Center    Italian Restaurant
# 39         Hudson Yards           Coffee Shop    Italian Restaurant
#
#      3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue  \
# 0              Yoga Studio            Steakhouse        Supplement Shop
# 1       Dim Sum Restaurant   American Restaurant  Vietnamese Restaurant
# 6        French Restaurant   American Restaurant         Cosmetics Shop
# 9                      Bar    Italian Restaurant       Sushi Restaurant
# 14             Coffee Shop   American Restaurant   Gym / Fitness Center
# 23           Women's Store            Shoe Store            Men's Store
# 26                    Park             Bookstore            Pizza Place
# 34  Furniture / Home Store     Indian Restaurant           Dessert Shop
# 39                   Hotel               Theater    American Restaurant
#
#      6th Most Common Venue 7th Most Common Venue     8th Most Common Venue  \
# 0           Tennis Stadium            Shoe Store                       Gym
# 1       Salon / Barbershop          Noodle House                    Bakery
# 6       Chinese Restaurant           Event Space              Liquor Store
# 9              Pizza Place    Mexican Restaurant             Deli / Bodega
# 14                   Hotel             Wine Shop                       Spa
# 23  Furniture / Home Store    Italian Restaurant  Mediterranean Restaurant
# 26          Sandwich Place          Burger Joint                      Café
# 34     American Restaurant                Bakery                 Juice Bar
# 39                    Café  Gym / Fitness Center           Thai Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 0                   Bank     Seafood Restaurant
# 1        Bubble Tea Shop         Ice Cream Shop
# 6               Beer Bar   Gym / Fitness Center
# 9    Japanese Restaurant                    Pub
# 14                   Gym          Indie Theater
# 23           Art Gallery          Design Studio
# 26         Deli / Bodega           Tennis Court
# 34              Boutique       Sushi Restaurant
# 39            Restaurant                    Gym

# %% [markdown]
# ## Map of Manhattan places for rent

# %%
# csv files with rental places with basic data but still wihtout geodata ( latitude and longitude)
# pd.read_csv(' le.csv', header=None, nrows=5)
body = client_03d269dcb9d842f3a697a2cdf4a866f1.get_object(Bucket='capstoneproject-donotdelete-pr-zmnovm1tp62gg3',Key='MH_flats_price.xlsx')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

mh_rent = pd.read_excel(body)
mh_rent.head()
# Out:
#              Address             Area  Price_per_ft2  Rooms  Area-ft2  \
# 0  West 105th Street  Upper West Side           2.94      5      3400
# 1   East 97th Street  Upper East Side           3.57      3      2100
# 2  West 105th Street  Upper West Side           1.89      4      2800
# 3        CARMINE ST.     West Village           3.03      2      1650
# 4    171 W 23RD ST.           Chelsea           3.45      2      1450
#
#    Rent_Price  Lat  Long
# 0       10000  NaN   NaN
# 1        7500  NaN   NaN
# 2        5300  NaN   NaN
# 3        5000  NaN   NaN
# 4        5000  NaN   NaN

# %%
mh_rent.tail()
# Out:
#                   Address                                Area  Price_per_ft2  \
# 139  200 East 72nd Street                Rental in Lenox Hill           5.15
# 140      50 Murray Street            No fee rental in Tribeca           7.11
# 141  300 East 56th Street       No fee rental in Midtown East           3.87
# 142         1930 Broadway  No fee rental in Central Park West           5.06
# 143    33 West 9th Street         Rental in Greenwich Village           6.67
#
#      Rooms  Area-ft2  Rent_Price  Lat  Long
# 139      3      1700        8750  NaN   NaN
# 140      2      1223        8700  NaN   NaN
# 141      3      2100        8118  NaN   NaN
# 142      2      1600        8095  NaN   NaN
# 143      2      1500       10000  NaN   NaN

# %% [markdown]
# ## Obtain geodata ( lat,long) for each rental place in Manhattan with Nominatim

# %%
for n in range(len(mh_rent)):
    address= mh_rent['Address'][n] 
    address=(mh_rent['Address'][n]+ ' , '+' Manhattan NY ') 
    geolocator = Nominatim() 
    location = geolocator.geocode(address) 
    latitude = location.latitude 
    longitude = location.longitude 
    mh_rent['Lat'][n]=latitude 
    mh_rent['Long'][n]=longitude

print(n,latitude,longitude)
time.sleep(2)

print('Geodata completed')
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:4: DeprecationWarning: Using Nominatim with the default "geopy/1.21.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 143 40.733691199999996 -73.99732284481132
# Geodata completed

# %% [markdown]
# ## save dataframe to csv file

# %%
mh_rent.to_csv('MH_rent_latlong.csv',index=False)
mh_rent.shape
# Out:
# (144, 8)

# %%
mh_rent=pd.read_csv('MH_rent_latlong.csv')
mh_rent.head()
# Out:
#              Address             Area  Price_per_ft2  Rooms  Area-ft2  \
# 0  West 105th Street  Upper West Side           2.94      5      3400
# 1   East 97th Street  Upper East Side           3.57      3      2100
# 2  West 105th Street  Upper West Side           1.89      4      2800
# 3        CARMINE ST.     West Village           3.03      2      1650
# 4    171 W 23RD ST.           Chelsea           3.45      2      1450
#
#    Rent_Price        Lat       Long
# 0       10000  40.799771 -73.966213
# 1        7500  40.788517 -73.955118
# 2        5300  40.799771 -73.966213
# 3        5000  40.730337 -74.002476
# 4        5000  40.744118 -73.995299

# %%
mh_rent.tail()
# Out:
#                   Address                                Area  Price_per_ft2  \
# 139  200 East 72nd Street                Rental in Lenox Hill           5.15
# 140      50 Murray Street            No fee rental in Tribeca           7.11
# 141  300 East 56th Street       No fee rental in Midtown East           3.87
# 142         1930 Broadway  No fee rental in Central Park West           5.06
# 143    33 West 9th Street         Rental in Greenwich Village           6.67
#
#      Rooms  Area-ft2  Rent_Price        Lat       Long
# 139      3      1700        8750  40.769465 -73.960339
# 140      2      1223        8700  40.714051 -74.009608
# 141      3      2100        8118  40.757915 -73.965319
# 142      2      1600        8095  40.772433 -73.981705
# 143      2      1500       10000  40.733691 -73.997323

# %% [markdown]
# ## Manhattan apartment rent price statistics

# %%
import seaborn as sns
sns.distplot(mh_rent['Rent_Price'],bins=15)

# %%
import seaborn as sns
sns.distplot(mh_rent['Price_per_ft2'],bins=15)

# %%
sns.boxplot(x='Rooms', y= 'Rent_Price', data=mh_rent)

# %% [markdown]
# ## Map of Manhattan apartments for rent

# %%
# create map of Manhattan using latitude and longitude values from Nominatim
latitude= 40.7308619
longitude= -73.9871558

map_manhattan_rent = folium.Map(location=[latitude, longitude], zoom_start=12.5)

# add markers to map
for lat, lng, label in zip(mh_rent['Lat'], mh_rent['Long'],'$ ' + mh_rent['Rent_Price'].astype(str)+ ',  '+ mh_rent['Address']):      
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=6,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan_rent) 
    

map_manhattan_rent
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# create map of Manhattan using latitude and longitude values from Nominatim
latitude= 40.7308619
longitude= -73.9871558

# create map with clusters
kclusters=5
map_clusters2 = folium.Map(location=[latitude, longitude], zoom_start=13)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Neighborhood'], manhattan_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=20,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters2)

# add markers to map for rental places
for lat, lng, label in zip(mh_rent['Lat'], mh_rent['Long'],'$ ' + mh_rent['Rent_Price'].astype(str)+ mh_rent['Address']):      
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=6,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_clusters2)  
    
    # Adds tool to the top right
from folium.plugins import MeasureControl
map_manhattan_rent.add_child(MeasureControl())

# FMeasurement ruler icon to establish distnces on map
from folium.plugins import FloatImage
url = ('https://media.licdn.com/mpr/mpr/shrinknp_100_100/AAEAAQAAAAAAAAlgAAAAJGE3OTA4YTdlLTkzZjUtNDFjYy1iZThlLWQ5OTNkYzlhNzM4OQ.jpg')
FloatImage(url, bottom=5, left=85).add_to(map_manhattan_rent)

map_clusters2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Now one can explore a particular rental place and its venues in detail

# %%
## kk is the cluster number to explore
kk = 3
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == kk, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#           Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 3               Inwood    Mexican Restaurant                Lounge
# 5       Manhattanville         Deli / Bodega    Italian Restaurant
# 10          Lenox Hill      Sushi Restaurant    Italian Restaurant
# 12     Upper West Side    Italian Restaurant                   Bar
# 16         Murray Hill        Sandwich Place                 Hotel
# 17             Chelsea           Coffee Shop    Italian Restaurant
# 18   Greenwich Village    Italian Restaurant      Sushi Restaurant
# 27            Gramercy    Italian Restaurant            Restaurant
# 29  Financial District           Coffee Shop                 Hotel
# 31                Noho    Italian Restaurant     French Restaurant
# 32        Civic Center  Gym / Fitness Center                Bakery
# 35          Turtle Bay    Italian Restaurant           Coffee Shop
# 36          Tudor City                  Café                  Park
# 38            Flatiron    Italian Restaurant   American Restaurant
#
#      3rd Most Common Venue          4th Most Common Venue  \
# 3              Pizza Place                           Café
# 5       Seafood Restaurant             Mexican Restaurant
# 10             Coffee Shop           Gym / Fitness Center
# 12                  Bakery  Vegetarian / Vegan Restaurant
# 16     Japanese Restaurant           Gym / Fitness Center
# 17          Ice Cream Shop                         Bakery
# 18       French Restaurant                 Clothing Store
# 27  Thrift / Vintage Store                   Cocktail Bar
# 29                     Gym                      Wine Shop
# 31            Cocktail Bar                      Gift Shop
# 32      Italian Restaurant                   Cocktail Bar
# 35              Steakhouse                       Wine Bar
# 36             Pizza Place             Mexican Restaurant
# 38                     Gym           Gym / Fitness Center
#
#    5th Most Common Venue          6th Most Common Venue 7th Most Common Venue  \
# 3               Wine Bar                         Bakery   American Restaurant
# 5       Sushi Restaurant                    Beer Garden           Coffee Shop
# 10           Pizza Place                   Burger Joint         Deli / Bodega
# 12     Indian Restaurant                    Coffee Shop        Cosmetics Shop
# 16           Coffee Shop             Salon / Barbershop          Burger Joint
# 17             Nightclub                        Theater           Art Gallery
# 18    Chinese Restaurant                           Café     Indian Restaurant
# 27            Bagel Shop                    Coffee Shop           Pizza Place
# 29            Steakhouse                            Bar    Italian Restaurant
# 31             Bookstore                  Grocery Store    Mexican Restaurant
# 32     French Restaurant                 Sandwich Place           Coffee Shop
# 35      Sushi Restaurant                          Hotel          Noodle House
# 36      Greek Restaurant               Sushi Restaurant                 Hotel
# 38           Yoga Studio  Vegetarian / Vegan Restaurant                Bakery
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 3                   Park    Frozen Yogurt Shop     Spanish Restaurant
# 5     Falafel Restaurant            Bike Trail        Other Nightlife
# 10                   Gym   Sporting Goods Shop        Thai Restaurant
# 12              Wine Bar    Mexican Restaurant       Sushi Restaurant
# 16     French Restaurant                   Bar     Italian Restaurant
# 17    Seafood Restaurant   American Restaurant                  Hotel
# 18                Bakery    Seafood Restaurant      Electronics Store
# 27    Mexican Restaurant         Grocery Store              Wine Shop
# 29           Pizza Place                  Park   Gym / Fitness Center
# 31                 Hotel      Sushi Restaurant            Coffee Shop
# 32                   Gym           Yoga Studio                   Park
# 35     Indian Restaurant   Japanese Restaurant      French Restaurant
# 36         Deli / Bodega                 Diner                Dog Run
# 38        Clothing Store        Cosmetics Shop           Cycle Studio

# %% [markdown]
# ## Mapping Manhattan Subway locations

# %%
# A csv file summarized the subway station and the addresses for next step to determine geodata
body = client_03d269dcb9d842f3a697a2cdf4a866f1.get_object(Bucket='capstoneproject-donotdelete-pr-zmnovm1tp62gg3',Key='NYC_subway_list.xlsx')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

mh = pd.read_excel(body)
mh.head()
# Out:
#                      sub_station                              sub_address
# 0  Dyckman Street Subway Station   170 Nagle Ave, New York, NY 10034, USA
# 1       57 Street Subway Station                  New York, NY 10106, USA
# 2                       Broad St                  New York, NY 10005, USA
# 3             175 Street Station  807 W 177th St, New York, NY 10033, USA
# 4                 5 Av and 53 St                  New York, NY 10022, USA

# %%
#  Add columns 'lat'  and 'long' to mh dataframe - with random temporary numbers to get started
sLength = len(mh['sub_station'])
lat = pd.Series(np.random.randn(sLength))
long=pd.Series(np.random.randn(sLength))
mh = mh.assign(lat=lat.values)
mh = mh.assign(long=long.values)

# %% [markdown]
# ## save dataframe to csv file

# %%
mh.to_csv('MH_subway.csv',index=False)
mh.shape
# Out:
# (76, 4)

# %%
mh=pd.read_csv('MH_subway.csv')
print(mh.shape)
mh.head()
# Out:
# (76, 4)
#                      sub_station                              sub_address  \
# 0  Dyckman Street Subway Station   170 Nagle Ave, New York, NY 10034, USA
# 1       57 Street Subway Station                  New York, NY 10106, USA
# 2                       Broad St                  New York, NY 10005, USA
# 3             175 Street Station  807 W 177th St, New York, NY 10033, USA
# 4                 5 Av and 53 St                  New York, NY 10022, USA
#
#         lat      long
# 0 -1.036327  0.247121
# 1  0.817529  0.453466
# 2  0.301122 -0.045106
# 3  0.893566  0.049837
# 4 -0.497527 -1.092186

# %%
# removing duplicate rows and creating new set mhsub1
mhsub1=mh.drop_duplicates(subset=['lat','long'], keep="last").reset_index(drop=True)
mhsub1.shape
# Out:
# (76, 4)

# %%
mhsub1.tail()
# Out:
#            sub_station                            sub_address       lat  \
# 71            50 St Br      New York, NY 10019, United States -1.047692
# 72   57 Street Station      New York, NY 10019, United States -0.366811
# 73   23 Street Station      New York, NY 10010, United States -0.965292
# 74    14 Street / 8 Av      New York, NY 10014, United States  0.523858
# 75  MTA New York City   525 11th Ave, New York, NY 10018, USA -0.984887
#
#         long
# 71  0.699014
# 72  1.213553
# 73 -0.386579
# 74 -0.858980
# 75  1.570998

# %% [markdown]
# ## MAP of Manhattan showing the location of subway stations

# %%
# map subway stations 
# create map of Manhattan using latitude and longitude values obtain previoulsy via Moninatim geolocator
latitude=40.7308619
longitude=-73.9871558

map_mhsub1 = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers of subway locations to map
for lat, lng, label in zip(mhsub1['lat'], mhsub1['long'],  mhsub1['sub_station'].astype(str) ):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=6,
        radius=6,
        popup=label,
        color='red',
        fill_color='red',
        fill_opacity=2.5,
    ).add_to(map_mhsub1) 
map_mhsub1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Map of Manhattan showing places for rent and the subway locations nearby

# %%
mh_rent.head()
# Out:
#              Address             Area  Price_per_ft2  Rooms  Area-ft2  \
# 0  West 105th Street  Upper West Side           2.94      5      3400
# 1   East 97th Street  Upper East Side           3.57      3      2100
# 2  West 105th Street  Upper West Side           1.89      4      2800
# 3        CARMINE ST.     West Village           3.03      2      1650
# 4    171 W 23RD ST.           Chelsea           3.45      2      1450
#
#    Rent_Price        Lat       Long
# 0       10000  40.799771 -73.966213
# 1        7500  40.788517 -73.955118
# 2        5300  40.799771 -73.966213
# 3        5000  40.730337 -74.002476
# 4        5000  40.744118 -73.995299

# %%
# create map of Manhattan using latitude and longitude values from Nominatim
latitude= 40.7308619
longitude= -73.9871558

map_manhattan_rent = folium.Map(location=[latitude, longitude], zoom_start=13.3)

# add markers to map
for lat, lng, label in zip(mh_rent['Lat'], mh_rent['Long'],'$ ' + mh_rent['Rent_Price'].astype(str)+ mh_rent['Address']):      
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=6,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan_rent) 
    
    # add markers of subway locations to map
for lat, lng, label in zip(mhsub1['lat'], mhsub1['long'],  mhsub1['sub_station'].astype(str) ):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=6,
        radius=6,
        popup=label,
        color='red',
        fill_color='red',
        fill_opacity=2.5,
    ).add_to(map_manhattan_rent) 
    
    # Adds tool to the top right
from folium.plugins import MeasureControl
map_manhattan_rent.add_child(MeasureControl())

# Measurement ruler icon tool to measure distances in map
from folium.plugins import FloatImage
url = ('https://media.licdn.com/mpr/mpr/shrinknp_100_100/AAEAAQAAAAAAAAlgAAAAJGE3OTA4YTdlLTkzZjUtNDFjYy1iZThlLWQ5OTNkYzlhNzM4OQ.jpg')
FloatImage(url, bottom=5, left=85).add_to(map_manhattan_rent)

map_manhattan_rent
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Map of Manhattan with rental places, subway locations and cluster of venues

# %%
# create map of Manhattan using latitude and longitude values from Nominatim
latitude= 40.7308619
longitude= -73.9871558

map_mh_one = folium.Map(location=[latitude, longitude], zoom_start=13.3)

# add markers to map
for lat, lng, label in zip(mh_rent['Lat'], mh_rent['Long'],'$ ' + mh_rent['Rent_Price'].astype(str)+ ', '+mh_rent['Address']):      
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=6,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_mh_one) 
    
    # add markers of subway locations to map
for lat, lng, label in zip(mhsub1['lat'], mhsub1['long'],  mhsub1['sub_station'].astype(str) ):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=6,
        radius=6,
        popup=label,
        color='red',
        fill_color='red',
        fill_opacity=2.5,
    ).add_to(map_mh_one) 


# set color scheme for the clusters
kclusters=5
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Neighborhood'], manhattan_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=15,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_mh_one)

    # Adds tool to the top right
from folium.plugins import MeasureControl
map_mh_one.add_child(MeasureControl())

# Measurement ruler icon tool to measure distances in map
from folium.plugins import FloatImage
url = ('https://media.licdn.com/mpr/mpr/shrinknp_100_100/AAEAAQAAAAAAAAlgAAAAJGE3OTA4YTdlLTkzZjUtNDFjYy1iZThlLWQ5OTNkYzlhNzM4OQ.jpg')
FloatImage(url, bottom=5, left=85).add_to(map_mh_one)

map_mh_one
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Problem Resolution - Select the apartment for rent

# %% [markdown]
# #### After examining, I have chosen two locations that meet the requirements which will assess to make a choice.
#
#     1. Apartment 1: 305 East 63rd Street in the Sutton Place Neighborhood and near 'subway 59th Street' station, Cluster # 2 Monthly rent : 7500 Dollars
#
#     2. Apartment 2: 19 Dutch Street in the Financial District Neighborhood and near 'Fulton Street Subway' station, Cluster # 3 Monthly rent : 6935 Dollars

# %% [markdown]
# #### Venues for Apartment 1 - Cluster 2

# %%
## kk is the cluster number to explore
kk = 2
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == kk, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#            Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0           Marble Hill           Coffee Shop        Discount Store
# 1             Chinatown    Chinese Restaurant          Cocktail Bar
# 6        Central Harlem    African Restaurant    Seafood Restaurant
# 9             Yorkville           Coffee Shop                   Gym
# 14              Clinton               Theater    Italian Restaurant
# 23                 Soho        Clothing Store              Boutique
# 26  Morningside Heights           Coffee Shop   American Restaurant
# 34         Sutton Place  Gym / Fitness Center    Italian Restaurant
# 39         Hudson Yards           Coffee Shop    Italian Restaurant
#
#      3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue  \
# 0              Yoga Studio            Steakhouse        Supplement Shop
# 1       Dim Sum Restaurant   American Restaurant  Vietnamese Restaurant
# 6        French Restaurant   American Restaurant         Cosmetics Shop
# 9                      Bar    Italian Restaurant       Sushi Restaurant
# 14             Coffee Shop   American Restaurant   Gym / Fitness Center
# 23           Women's Store            Shoe Store            Men's Store
# 26                    Park             Bookstore            Pizza Place
# 34  Furniture / Home Store     Indian Restaurant           Dessert Shop
# 39                   Hotel               Theater    American Restaurant
#
#      6th Most Common Venue 7th Most Common Venue     8th Most Common Venue  \
# 0           Tennis Stadium            Shoe Store                       Gym
# 1       Salon / Barbershop          Noodle House                    Bakery
# 6       Chinese Restaurant           Event Space              Liquor Store
# 9              Pizza Place    Mexican Restaurant             Deli / Bodega
# 14                   Hotel             Wine Shop                       Spa
# 23  Furniture / Home Store    Italian Restaurant  Mediterranean Restaurant
# 26          Sandwich Place          Burger Joint                      Café
# 34     American Restaurant                Bakery                 Juice Bar
# 39                    Café  Gym / Fitness Center           Thai Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 0                   Bank     Seafood Restaurant
# 1        Bubble Tea Shop         Ice Cream Shop
# 6               Beer Bar   Gym / Fitness Center
# 9    Japanese Restaurant                    Pub
# 14                   Gym          Indie Theater
# 23           Art Gallery          Design Studio
# 26         Deli / Bodega           Tennis Court
# 34              Boutique       Sushi Restaurant
# 39            Restaurant                    Gym

# %% [markdown]
# #### Venues for Apartment 2 - Cluster 3

# %%
## kk is the cluster number to explore
kk = 3
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == kk, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#           Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 3               Inwood    Mexican Restaurant                Lounge
# 5       Manhattanville         Deli / Bodega    Italian Restaurant
# 10          Lenox Hill      Sushi Restaurant    Italian Restaurant
# 12     Upper West Side    Italian Restaurant                   Bar
# 16         Murray Hill        Sandwich Place                 Hotel
# 17             Chelsea           Coffee Shop    Italian Restaurant
# 18   Greenwich Village    Italian Restaurant      Sushi Restaurant
# 27            Gramercy    Italian Restaurant            Restaurant
# 29  Financial District           Coffee Shop                 Hotel
# 31                Noho    Italian Restaurant     French Restaurant
# 32        Civic Center  Gym / Fitness Center                Bakery
# 35          Turtle Bay    Italian Restaurant           Coffee Shop
# 36          Tudor City                  Café                  Park
# 38            Flatiron    Italian Restaurant   American Restaurant
#
#      3rd Most Common Venue          4th Most Common Venue  \
# 3              Pizza Place                           Café
# 5       Seafood Restaurant             Mexican Restaurant
# 10             Coffee Shop           Gym / Fitness Center
# 12                  Bakery  Vegetarian / Vegan Restaurant
# 16     Japanese Restaurant           Gym / Fitness Center
# 17          Ice Cream Shop                         Bakery
# 18       French Restaurant                 Clothing Store
# 27  Thrift / Vintage Store                   Cocktail Bar
# 29                     Gym                      Wine Shop
# 31            Cocktail Bar                      Gift Shop
# 32      Italian Restaurant                   Cocktail Bar
# 35              Steakhouse                       Wine Bar
# 36             Pizza Place             Mexican Restaurant
# 38                     Gym           Gym / Fitness Center
#
#    5th Most Common Venue          6th Most Common Venue 7th Most Common Venue  \
# 3               Wine Bar                         Bakery   American Restaurant
# 5       Sushi Restaurant                    Beer Garden           Coffee Shop
# 10           Pizza Place                   Burger Joint         Deli / Bodega
# 12     Indian Restaurant                    Coffee Shop        Cosmetics Shop
# 16           Coffee Shop             Salon / Barbershop          Burger Joint
# 17             Nightclub                        Theater           Art Gallery
# 18    Chinese Restaurant                           Café     Indian Restaurant
# 27            Bagel Shop                    Coffee Shop           Pizza Place
# 29            Steakhouse                            Bar    Italian Restaurant
# 31             Bookstore                  Grocery Store    Mexican Restaurant
# 32     French Restaurant                 Sandwich Place           Coffee Shop
# 35      Sushi Restaurant                          Hotel          Noodle House
# 36      Greek Restaurant               Sushi Restaurant                 Hotel
# 38           Yoga Studio  Vegetarian / Vegan Restaurant                Bakery
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 3                   Park    Frozen Yogurt Shop     Spanish Restaurant
# 5     Falafel Restaurant            Bike Trail        Other Nightlife
# 10                   Gym   Sporting Goods Shop        Thai Restaurant
# 12              Wine Bar    Mexican Restaurant       Sushi Restaurant
# 16     French Restaurant                   Bar     Italian Restaurant
# 17    Seafood Restaurant   American Restaurant                  Hotel
# 18                Bakery    Seafood Restaurant      Electronics Store
# 27    Mexican Restaurant         Grocery Store              Wine Shop
# 29           Pizza Place                  Park   Gym / Fitness Center
# 31                 Hotel      Sushi Restaurant            Coffee Shop
# 32                   Gym           Yoga Studio                   Park
# 35     Indian Restaurant   Japanese Restaurant      French Restaurant
# 36         Deli / Bodega                 Diner                Dog Run
# 38        Clothing Store        Cosmetics Shop           Cycle Studio

# %% [markdown]
# #### Apartment Selection
# Using the "one map" above, I was able to explore all possibilities since the popups provide the information needed for a good decision.
# Apartment 1 rent cost is US7500 slightly above the US7000 budget. Apt 1 is located 400 meters from subway station at 59th Street and work place ( Park Ave and 53rd) is another 600 meters way. I can walk to work place and use subway for other places aroung. Venues for this apt are as of Cluster 2 and it is located in a fine district in the East side of Manhattan.
# Apartment 2 rent cost is US6935, just under the US7000 budget. Apt 2 is located 60 meters from subway station at Fulton Street, but I will have to ride the subway daily to work , possibly 40-60 min ride. Venues for this apt are as of Cluster 3.

# %% [markdown]
# ### Based on current Singapore venues, I feel that Cluster 2 type of venues is a closer resemblance to my current place. That means that APARTMENT 1 is a better choice since the extra monthly rent is worth the conveniences it provides.
